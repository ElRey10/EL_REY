# %% [markdown]
# <a href="https://colab.research.google.com/github/ElRey10/EL_REY/blob/master/pythonnote4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
board = ["", " ", " ", " ", " ", " ", " ", " ", " ", " "]
def print_board():
	print ("   |   |   ")
	print (" "+board[1]+" | "+board[2]+" | "+board[3]+"  ")
	print ("   |   |   ")
	print ("---|---|---")
	print ("   |   |   ")
	print (" "+board[4]+" | "+board[5]+" | "+board[6]+"  ")
	print ("   |   |   ")
	print ("---|---|---")
	print ("   |   |   ")			
	print (" "+board[7]+" | "+board[8]+" | "+board[9]+"  ")
	print ("   |   |   ")
	if(cnt>0):
		print("                   ")
		print(cnt," move done")
		print("                   ")
	
def is_winner(board, player):
	if (board[1] == player and board[2] == player and board[3] == player) or \
		(board[4] == player and board[5] == player and board[6] == player) or \
		(board[7] == player and board[8] == player and board[9] == player) or \
		(board[1] == player and board[4] == player and board[7] == player) or \
		(board[2] == player and board[5] == player and board[8] == player) or \
		(board[3] == player and board[6] == player and board[9] == player) or \
		(board[1] == player and board[5] == player and board[9] == player) or \
		(board[3] == player and board[5] == player and board[7] == player):
		return True
	else:
		return False
		
def is_board_full(board):
	if " " in board:
		return False
	else:
		return True
		
def get_computer_move(board, player):
	if board[5] == " ":
		return 5

	while True:
		move = random.randint(1,9)
		
		if board[move] == " ":
			return move
			break
			
	return 5
cnt=0	
while True:
	print_board()
	cnt=cnt+1		
	choice = input("Please choose an empty space for X(From 1-9). ")
	choice = int(choice)
	if board[choice] == " ":
		board[choice] = "X"
	else:
		print ("Sorry, that space is not empty!")
		
	if is_winner(board, "X"):
		print_board()
		print ("You(X) wins! Congratulations")
		break
	print_board()

	if is_board_full(board):
		print ("Tie!")
		break
	
	choice = get_computer_move(board,  "O")
	
	if board[choice] == " ":
		board[choice] = "O"
	else:
		print ("Sorry, that space is not empty!")
		
	if is_winner(board, "O"):
		print_board()
		print ("PC (O) wins! ")
		break
	
	if is_board_full(board):
		print ("Tie!")
		break
# Out:
#    |   |
#    |   |
#    |   |
# ---|---|---
#    |   |
#    |   |
#    |   |
# ---|---|---
#    |   |
#    |   |
#    |   |
# Please choose an empty space for X(From 1-9).  2
#    |   |
#    | X |
#    |   |
# ---|---|---
#    |   |
#    |   |
#    |   |
# ---|---|---
#    |   |
#    |   |
#    |   |
#
# 1  move done
#
#    |   |
#    | X |
#    |   |
# ---|---|---
#    |   |
#    | O |
#    |   |
# ---|---|---
#    |   |
#    |   |
#    |   |
#
# 1  move done
#
# Please choose an empty space for X(From 1-9). 3
#    |   |
#    | X | X
#    |   |
# ---|---|---
#    |   |
#    | O |
#    |   |
# ---|---|---
#    |   |
#    |   |
#    |   |
#
# 2  move done
#
#    |   |
#    | X | X
#    |   |
# ---|---|---
#    |   |
#    | O |
#    |   |
# ---|---|---
#    |   |
#    | O |
#    |   |
#
# 2  move done
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ...
